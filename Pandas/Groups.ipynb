# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Carga de Datos de trafico

# %%
df = pd.read_csv('/home/dsc/Data/us_dot/otp/On_Time_On_Time_Performance_2015_1.csv')
# Out:
# /usr/lib64/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (77,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0  2015        1      1           1          4  2015-01-01            AA
# 1  2015        1      1           2          5  2015-01-02            AA
# 2  2015        1      1           3          6  2015-01-03            AA
# 3  2015        1      1           4          7  2015-01-04            AA
# 4  2015        1      1           5          1  2015-01-05            AA
#
#    AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 0      19805      AA  N787AA      ...               NaN          NaN
# 1      19805      AA  N795AA      ...               NaN          NaN
# 2      19805      AA  N788AA      ...               NaN          NaN
# 3      19805      AA  N791AA      ...               NaN          NaN
# 4      19805      AA  N783AA      ...               NaN          NaN
#
#    Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# ...

# %%
df[['FlightDate','Carrier']].sample(5)
# Out:
#         FlightDate Carrier
# 462468  2015-01-01      MQ
# 169392  2015-01-11      US
# 36973   2015-01-07      AA
# 363060  2015-01-25      DL
# 90915   2015-01-08      DL

# %%
df[df['FlightDate']=='2015-01-22'].sample(5)
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 229891  2015        1      1          22          4  2015-01-22            WN
# 304594  2015        1      1          22          4  2015-01-22            UA
# 229879  2015        1      1          22          4  2015-01-22            WN
# 275394  2015        1      1          22          4  2015-01-22            MQ
# 299251  2015        1      1          22          4  2015-01-22            UA
#
#         AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 229891      19393      WN  N942WN      ...               NaN          NaN
# 304594      19977      UA  N491UA      ...               NaN          NaN
# 229879      19393      WN  N202WN      ...               NaN          NaN
# 275394      20398      MQ  N838MQ      ...               NaN          NaN
# 299251      19977      UA  N69819      ...               NaN          NaN
#
# ...

# %%
df[(df['DayofMonth']==22) & (df["Month"]==1) & (df['Year']==2015)].sample(5)
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 352571  2015        1      1          22          4  2015-01-22            DL
# 198378  2015        1      1          22          4  2015-01-22            WN
# 415295  2015        1      1          22          4  2015-01-22            DL
# 281427  2015        1      1          22          4  2015-01-22            OO
# 356511  2015        1      1          22          4  2015-01-22            DL
#
#         AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 352571      19790      DL  N374NW      ...               NaN          NaN
# 198378      19393      WN  N752SW      ...               NaN          NaN
# 415295      19790      DL  N926DH      ...               NaN          NaN
# 281427      20304      OO  N117SY      ...               NaN          NaN
# 356511      19790      DL  N957AT      ...               NaN          NaN
#
# ...

# %%
df.dtypes
# Out:
# Year                    int64
# Quarter                 int64
# Month                   int64
# DayofMonth              int64
# DayOfWeek               int64
# FlightDate             object
# UniqueCarrier          object
# AirlineID               int64
# Carrier                object
# TailNum                object
# FlightNum               int64
# OriginAirportID         int64
# OriginAirportSeqID      int64
# OriginCityMarketID      int64
# Origin                 object
# OriginCityName         object
# OriginState            object
# OriginStateFips         int64
# OriginStateName        object
# OriginWac               int64
# DestAirportID           int64
# DestAirportSeqID        int64
# DestCityMarketID        int64
# Dest                   object
# DestCityName           object
# DestState              object
# DestStateFips           int64
# DestStateName          object
# DestWac                 int64
# CRSDepTime              int64
#                        ...
# ...

# %%
df1 = DataFrame(np.random.randint(0,10,3*5).reshape(3,5))
df1.columns = ['c1','c2','c3','c4','c5']
df1
# Out:
#    c1  c2  c3  c4  c5
# 0   6   5   5   9   0
# 1   8   7   9   2   8
# 2   8   1   3   7   6

# %%
df1['key1'] = ['a','a','b']
df1
# Out:
#    c1  c2  c3  c4  c5 key1
# 0   6   5   5   9   0    a
# 1   8   7   9   2   8    a
# 2   8   1   3   7   6    b

# %%
df2 = DataFrame(np.random.randint(0,10,3*5).reshape(3,5))
df2.columns = ['c1','c2','c3','c4','c5']

# %%
df2['key1'] = ['b','a','b']
df2
# Out:
#    c1  c2  c3  c4  c5 key1
# 0   4   5   3   2   1    b
# 1   1   1   4   2   2    a
# 2   5   9   2   4   5    b

# %%
pd.merge(df1,df2, on='key1')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1  c1_y  c2_y  c3_y  c4_y  c5_y
# 0     6     5     5     9     0    a     1     1     4     2     2
# 1     8     7     9     2     8    a     1     1     4     2     2
# 2     8     1     3     7     6    b     4     5     3     2     1
# 3     8     1     3     7     6    b     5     9     2     4     5

# %%
pd.merge(df1,df2, on='key1', how='inner')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1  c1_y  c2_y  c3_y  c4_y  c5_y
# 0     6     5     5     9     0    a     1     1     4     2     2
# 1     8     7     9     2     8    a     1     1     4     2     2
# 2     8     1     3     7     6    b     4     5     3     2     1
# 3     8     1     3     7     6    b     5     9     2     4     5

# %%
pd.merge(df1,df2, on='key1', how='outer')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1  c1_y  c2_y  c3_y  c4_y  c5_y
# 0     6     5     5     9     0    a     1     1     4     2     2
# 1     8     7     9     2     8    a     1     1     4     2     2
# 2     8     1     3     7     6    b     4     5     3     2     1
# 3     8     1     3     7     6    b     5     9     2     4     5

# %%
pd.merge(df1,df2, on='key1', how='left')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1  c1_y  c2_y  c3_y  c4_y  c5_y
# 0     6     5     5     9     0    a     1     1     4     2     2
# 1     8     7     9     2     8    a     1     1     4     2     2
# 2     8     1     3     7     6    b     4     5     3     2     1
# 3     8     1     3     7     6    b     5     9     2     4     5

# %%
pd.merge(df1,df2, on='key1', how='right')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1  c1_y  c2_y  c3_y  c4_y  c5_y
# 0     6     5     5     9     0    a     1     1     4     2     2
# 1     8     7     9     2     8    a     1     1     4     2     2
# 2     8     1     3     7     6    b     4     5     3     2     1
# 3     8     1     3     7     6    b     5     9     2     4     5

# %%
df2['key2'] = df1['key1']

# %%
df2
# Out:
#    c1  c2  c3  c4  c5 key1 key2
# 0   4   5   3   2   1    b    a
# 1   1   1   4   2   2    a    a
# 2   5   9   2   4   5    b    b

# %%
pd.merge(df1,df2, left_on='key1', right_on='key2')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1_x  c1_y  c2_y  c3_y  c4_y  c5_y key1_y  \
# 0     6     5     5     9     0      a     4     5     3     2     1      b
# 1     6     5     5     9     0      a     1     1     4     2     2      a
# 2     8     7     9     2     8      a     4     5     3     2     1      b
# 3     8     7     9     2     8      a     1     1     4     2     2      a
# 4     8     1     3     7     6      b     5     9     2     4     5      b
#
#   key2
# 0    a
# 1    a
# 2    a
# 3    a
# 4    b

# %%
pd.merge(df1,df2, left_on='key1', right_on='key2', suffixes=("izq","der"))
# Out:
#    c1izq  c2izq  c3izq  c4izq  c5izq key1izq  c1der  c2der  c3der  c4der  \
# 0      6      5      5      9      0       a      4      5      3      2
# 1      6      5      5      9      0       a      1      1      4      2
# 2      8      7      9      2      8       a      4      5      3      2
# 3      8      7      9      2      8       a      1      1      4      2
# 4      8      1      3      7      6       b      5      9      2      4
#
#    c5der key1der key2
# 0      1       b    a
# 1      2       a    a
# 2      1       b    a
# 3      2       a    a
# 4      5       b    b

# %%
ns =[1,2,3,4,5,'b','c']

# %%
df2 = df2.append({'c1':2,'c2':3,'c3':5,'c4':6,'c5':5,'key1':'d','key2':'c'},ignore_index='True',)
df2
# Out:
#    c1  c2  c3  c4  c5 key1 key2
# 0   4   5   3   2   1    b    a
# 1   1   1   4   2   2    a    a
# 2   5   9   2   4   5    b    b
# 3   2   3   5   6   5    d    c
# 4   2   3   5   6   5    d    c

# %%
df1
# Out:
#    c1  c2  c3  c4  c5 key1 key2
# 0   6   5   5   9   0    a    e
# 1   8   7   9   2   8    a    e
# 2   8   1   3   7   6    b    e

# %%
df1['key2']='e'
df1
# Out:
#    c1  c2  c3  c4  c5 key1 key2
# 0   6   5   5   9   0    a    e
# 1   8   7   9   2   8    a    e
# 2   8   1   3   7   6    b    e

# %%
pd.concat([df1,df2],ignore_index=True)
# Out:
#    c1  c2  c3  c4  c5 key1 key2
# 0   6   5   5   9   0    a    e
# 1   8   7   9   2   8    a    e
# 2   8   1   3   7   6    b    e
# 3   4   5   3   2   1    b    a
# 4   1   1   4   2   2    a    a
# 5   5   9   2   4   5    b    b
# 6   2   3   5   6   5    d    c
# 7   2   3   5   6   5    d    c

# %%
pd.merge(df1,df2, left_on='key1',right_on='key2', how='inner')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1_x key2_x  c1_y  c2_y  c3_y  c4_y  c5_y  \
# 0     6     5     5     9     0      a      e     4     5     3     2     1
# 1     6     5     5     9     0      a      e     1     1     4     2     2
# 2     8     7     9     2     8      a      e     4     5     3     2     1
# 3     8     7     9     2     8      a      e     1     1     4     2     2
# 4     8     1     3     7     6      b      e     5     9     2     4     5
#
#   key1_y key2_y
# 0      b      a
# 1      a      a
# 2      b      a
# 3      a      a
# 4      b      b

# %%
pd.merge(df1,df2, left_on='key1',right_on='key2', how='outer')
# Out:
#    c1_x  c2_x  c3_x  c4_x  c5_x key1_x key2_x  c1_y  c2_y  c3_y  c4_y  c5_y  \
# 0     6     5     5     9     0      a      e     4     5     3     2     1
# 1     6     5     5     9     0      a      e     1     1     4     2     2
# 2     8     7     9     2     8      a      e     4     5     3     2     1
# 3     8     7     9     2     8      a      e     1     1     4     2     2
# 4     8     1     3     7     6      b      e     5     9     2     4     5
# 5   NaN   NaN   NaN   NaN   NaN    NaN    NaN     2     3     5     6     5
# 6   NaN   NaN   NaN   NaN   NaN    NaN    NaN     2     3     5     6     5
#
#   key1_y key2_y
# 0      b      a
# 1      a      a
# 2      b      a
# 3      a      a
# 4      b      b
# 5      d      c
# 6      d      c

# %%
len(df)
# Out:
# 469968

# %%
minidf = df[ df['FlightDate']=='2015-01-22']

# %%
len(minidf)
# Out:
# 16013

# %%
by_carrier = minidf.groupby('Carrier')

# %%
by_carrier

# %%
by_carrier.get_group('AA').sample(5)
# Out:
#        Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 503    2015        1      1          22          4  2015-01-22            AA
# 1616   2015        1      1          22          4  2015-01-22            AA
# 30820  2015        1      1          22          4  2015-01-22            AA
# 9683   2015        1      1          22          4  2015-01-22            AA
# 26611  2015        1      1          22          4  2015-01-22            AA
#
#        AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 503        19805      AA  N798AA      ...               NaN          NaN
# 1616       19805      AA  N3JLAA      ...               NaN          NaN
# 30820      19805      AA  N568AA      ...               NaN          NaN
# 9683       19805      AA  N567AA      ...               NaN          NaN
# 26611      19805      AA  N200AA      ...               NaN          NaN
#
# ...

# %%
by_carrier.groups.keys()
# Out:
# ['AA',
#  'OO',
#  'DL',
#  'NK',
#  'HA',
#  'WN',
#  'B6',
#  'US',
#  'AS',
#  'MQ',
#  'F9',
#  'VX',
#  'EV',
#  'UA']

# %%
minidf.groupby(['Carrier','Origin'])

# %%
by_carrier

# %%
by_carrier.sum()
# Out:
#             Year  Quarter  Month  DayofMonth  DayOfWeek  AirlineID  FlightNum  \
# Carrier
# AA       2907645     1443   1443       31746       5772   28578615    1814608
# AS        878540      436    436        9592       1744    8689480     190953
# B6       1430650      710    710       15620       2840   14490390     645334
# DL       4642560     2304   2304       50688       9216   45596160    3818469
# EV       3481920     1728   1728       38016       6912   35192448    8412289
# F9        449345      223    223        4906        892    4557228     178800
# HA        419120      208    208        4576        832    4095520      47658
# MQ       2033135     1009   1009       22198       4036   20581582    3321753
# NK        566215      281    281        6182       1124    5736896     149452
# OO       3256240     1616   1616       35552       6464   32811264    8272753
# UA       2710175     1345   1345       29590       5380   26869065    1348184
# ...

# %%
by_carrier.get_group('AA').sum()
# Out:
# Year                       2907645
# Quarter                       1443
# Month                         1443
# DayofMonth                   31746
# DayOfWeek                     5772
# AirlineID                 28578615
# FlightNum                  1814608
# OriginAirportID           18172433
# OriginAirportSeqID      1817247207
# OriginCityMarketID        45364134
# OriginStateFips              43798
# OriginWac                    83513
# DestAirportID             18175896
# DestAirportSeqID        1817593504
# DestCityMarketID          45375380
# DestStateFips                43829
# DestWac                      83533
# CRSDepTime                 1912651
# DepTime                    1912824
# DepDelay                      6968
# DepDelayMinutes              11754
# DepDel15                       201
# DepartureDelayGroups          -394
# TaxiOut                      23642
# WheelsOff                  1947254
# WheelsOn                   2208690
# TaxiIn                       12518
# ...

# %%
by_carrier.sum()
# Out:
#             Year  Quarter  Month  DayofMonth  DayOfWeek  AirlineID  FlightNum  \
# Carrier
# AA       2907645     1443   1443       31746       5772   28578615    1814608
# AS        878540      436    436        9592       1744    8689480     190953
# B6       1430650      710    710       15620       2840   14490390     645334
# DL       4642560     2304   2304       50688       9216   45596160    3818469
# EV       3481920     1728   1728       38016       6912   35192448    8412289
# F9        449345      223    223        4906        892    4557228     178800
# HA        419120      208    208        4576        832    4095520      47658
# MQ       2033135     1009   1009       22198       4036   20581582    3321753
# NK        566215      281    281        6182       1124    5736896     149452
# OO       3256240     1616   1616       35552       6464   32811264    8272753
# UA       2710175     1345   1345       29590       5380   26869065    1348184
# ...

# %%
len(by_carrier.get_group('AA'))
# Out:
# 1443

# %%
by_carrier.get_group('AA')['Year'].count()
# Out:
# 1443

# %%
numberOfFlights = by_carrier['Year'].count()

# %%
numberOfFlights
# Out:
# Carrier
# AA    1443
# AS     436
# B6     710
# DL    2304
# EV    1728
# F9     223
# HA     208
# MQ    1009
# NK     281
# OO    1616
# UA    1345
# US    1171
# VX     163
# WN    3376
# Name: Year, dtype: int64

# %%
def dflength(df):
    return len(df)

# %%
by_carrier.apply(dflength)
# Out:
# Carrier
# AA    1443
# AS     436
# B6     710
# DL    2304
# EV    1728
# F9     223
# HA     208
# MQ    1009
# NK     281
# OO    1616
# UA    1345
# US    1171
# VX     163
# WN    3376
# dtype: int64

# %%
#Numero de vuelos para el 23 de enero

# minidf creation
minidf2 = df[ df['FlightDate']=='2015-01-23']
# crear group
by_carrier2 = minidf2.groupby('Carrier')
# len aggregation
by_carrier2.apply(dflength)
# Out:
# Carrier
# AA    1445
# AS     439
# B6     709
# DL    2303
# EV    1743
# F9     229
# HA     222
# MQ    1010
# NK     285
# OO    1625
# UA    1345
# US    1170
# VX     167
# WN    3364
# dtype: int64

# %%
df22jan = by_carrier.apply(dflength).reset_index()
df22jan
# Out:
#    Carrier     0
# 0       AA  1443
# 1       AS   436
# 2       B6   710
# 3       DL  2304
# 4       EV  1728
# 5       F9   223
# 6       HA   208
# 7       MQ  1009
# 8       NK   281
# 9       OO  1616
# 10      UA  1345
# 11      US  1171
# 12      VX   163
# 13      WN  3376

# %%
df23jan = by_carrier2.apply(dflength).reset_index()
df23jan
# Out:
#    Carrier     0
# 0       AA  1445
# 1       AS   439
# 2       B6   709
# 3       DL  2303
# 4       EV  1743
# 5       F9   229
# 6       HA   222
# 7       MQ  1010
# 8       NK   285
# 9       OO  1625
# 10      UA  1345
# 11      US  1170
# 12      VX   167
# 13      WN  3364

# %%
evodf = pd.merge(df22jan,df23jan,on='Carrier')

# %%
evodf.columns = ['Carrier','22 jan', '23 jan']

# %%
evodf
# Out:
#    Carrier  22 jan  23 jan
# 0       AA    1443    1445
# 1       AS     436     439
# 2       B6     710     709
# 3       DL    2304    2303
# 4       EV    1728    1743
# 5       F9     223     229
# 6       HA     208     222
# 7       MQ    1009    1010
# 8       NK     281     285
# 9       OO    1616    1625
# 10      UA    1345    1345
# 11      US    1171    1170
# 12      VX     163     167
# 13      WN    3376    3364

# %%
evodf['Evolution'] = 100 * (evodf['23 jan']-evodf['22 jan'])/evodf['22 jan']

# %%
evodf['percent'] = np.round(100 * (evodf['23 jan']-evodf['22 jan'])/evodf['22 jan'],2)
evodf
# Out:
#    Carrier  22 jan  23 jan  percent  Evolution
# 0       AA    1443    1445     0.14   0.138600
# 1       AS     436     439     0.69   0.688073
# 2       B6     710     709    -0.14  -0.140845
# 3       DL    2304    2303    -0.04  -0.043403
# 4       EV    1728    1743     0.87   0.868056
# 5       F9     223     229     2.69   2.690583
# 6       HA     208     222     6.73   6.730769
# 7       MQ    1009    1010     0.10   0.099108
# 8       NK     281     285     1.42   1.423488
# 9       OO    1616    1625     0.56   0.556931
# 10      UA    1345    1345     0.00   0.000000
# 11      US    1171    1170    -0.09  -0.085397
# 12      VX     163     167     2.45   2.453988
# 13      WN    3376    3364    -0.36  -0.355450

# %%
def dec2(n):
    return round(n,2)

# %%
evodf["Evolution2"] = evodf["Evolution"].apply(dec2)

# %%
evodf
# Out:
#    Carrier  22 jan  23 jan  percent  Evolution  Evolution2
# 0       AA    1443    1445     0.14   0.138600        0.14
# 1       AS     436     439     0.69   0.688073        0.69
# 2       B6     710     709    -0.14  -0.140845       -0.14
# 3       DL    2304    2303    -0.04  -0.043403       -0.04
# 4       EV    1728    1743     0.87   0.868056        0.87
# 5       F9     223     229     2.69   2.690583        2.69
# 6       HA     208     222     6.73   6.730769        6.73
# 7       MQ    1009    1010     0.10   0.099108        0.10
# 8       NK     281     285     1.42   1.423488        1.42
# 9       OO    1616    1625     0.56   0.556931        0.56
# 10      UA    1345    1345     0.00   0.000000        0.00
# 11      US    1171    1170    -0.09  -0.085397       -0.09
# 12      VX     163     167     2.45   2.453988        2.45
# 13      WN    3376    3364    -0.36  -0.355450       -0.36

# %%
evodf.sort("Evolution2", ascending=False)
# Out:
#    Carrier  22 jan  23 jan  percent  Evolution  Evolution2
# 6       HA     208     222     6.73   6.730769        6.73
# 5       F9     223     229     2.69   2.690583        2.69
# 12      VX     163     167     2.45   2.453988        2.45
# 8       NK     281     285     1.42   1.423488        1.42
# 4       EV    1728    1743     0.87   0.868056        0.87
# 1       AS     436     439     0.69   0.688073        0.69
# 9       OO    1616    1625     0.56   0.556931        0.56
# 0       AA    1443    1445     0.14   0.138600        0.14
# 7       MQ    1009    1010     0.10   0.099108        0.10
# 10      UA    1345    1345     0.00   0.000000        0.00
# 3       DL    2304    2303    -0.04  -0.043403       -0.04
# 11      US    1171    1170    -0.09  -0.085397       -0.09
# 2       B6     710     709    -0.14  -0.140845       -0.14
# 13      WN    3376    3364    -0.36  -0.355450       -0.36

# %%
def evo(s):
    return (s['23 jan']-s['22 jan'])/s['23 jan']

# %%
fila = evodf.ix[9]

# %%
fila
# Out:
# Carrier              OO
# 22 jan             1616
# 23 jan             1625
# percent            0.56
# Evolution     0.5569307
# Evolution2         0.56
# Evolution4            0
# Name: 9, dtype: object

# %%
evo(fila)
# Out:
# 0

# %%
evodf.apply(evo,axis=1)
# Out:
# 0     0
# 1     0
# 2    -1
# 3    -1
# 4     0
# 5     0
# 6     0
# 7     0
# 8     0
# 9     0
# 10    0
# 11   -1
# 12    0
# 13   -1
# dtype: int64

# %%
evodf['Evolution4'] = evodf.apply(evo, axis=1)

# %%
def evo2(s):
    fe22 = float(s['22 jan'])
    fe23 = float(s['23 jan'])
    return (fe23-fe22)/fe23

# %%
evodf.apply(evo2, axis=1)
# Out:
# 0     0.001384
# 1     0.006834
# 2    -0.001410
# 3    -0.000434
# 4     0.008606
# 5     0.026201
# 6     0.063063
# 7     0.000990
# 8     0.014035
# 9     0.005538
# 10    0.000000
# 11   -0.000855
# 12    0.023952
# 13   -0.003567
# dtype: float64

# %%
evodf
# Out:
#    Carrier  22 jan  23 jan  percent  Evolution  Evolution2  Evolution4
# 0       AA    1443    1445     0.14   0.138600        0.14           0
# 1       AS     436     439     0.69   0.688073        0.69           0
# 2       B6     710     709    -0.14  -0.140845       -0.14          -1
# 3       DL    2304    2303    -0.04  -0.043403       -0.04          -1
# 4       EV    1728    1743     0.87   0.868056        0.87           0
# 5       F9     223     229     2.69   2.690583        2.69           0
# 6       HA     208     222     6.73   6.730769        6.73           0
# 7       MQ    1009    1010     0.10   0.099108        0.10           0
# 8       NK     281     285     1.42   1.423488        1.42           0
# 9       OO    1616    1625     0.56   0.556931        0.56           0
# 10      UA    1345    1345     0.00   0.000000        0.00           0
# 11      US    1171    1170    -0.09  -0.085397       -0.09          -1
# ...

# %%
loc = range(len(evodf))
plt.bar(loc, evodf['Evolution2'])
plt.xticks(loc, evodf['Carrier'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#Create a new df evodfs (orderer by Evolution2)
#Plot the chart

# %%
evodfs = evodf.sort('Evolution2', ascending=False).reset_index()

# %%
loc = range(len(evodfs))
plt.bar(loc, evodfs['Evolution2'])
plt.xticks(loc, evodfs['Carrier'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
by_carrier

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(evodf['Evolution2'])
# Out:
# pandas.core.series.Series

# %%
by_carrier.first()
# Out:
#          Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# Carrier
# AA       2015        1      1          22          4  2015-01-22
# AS       2015        1      1          22          4  2015-01-22
# B6       2015        1      1          22          4  2015-01-22
# DL       2015        1      1          22          4  2015-01-22
# EV       2015        1      1          22          4  2015-01-22
# F9       2015        1      1          22          4  2015-01-22
# HA       2015        1      1          22          4  2015-01-22
# MQ       2015        1      1          22          4  2015-01-22
# NK       2015        1      1          22          4  2015-01-22
# OO       2015        1      1          22          4  2015-01-22
# UA       2015        1      1          22          4  2015-01-22
# US       2015        1      1          22          4  2015-01-22
# VX       2015        1      1          22          4  2015-01-22
# ...

# %%
by_carrier.mean()
# Out:
#          Year  Quarter  Month  DayofMonth  DayOfWeek  AirlineID    FlightNum  \
# Carrier
# AA       2015        1      1          22          4      19805  1257.524602
# AS       2015        1      1          22          4      19930   437.965596
# B6       2015        1      1          22          4      20409   908.921127
# DL       2015        1      1          22          4      19790  1657.321615
# EV       2015        1      1          22          4      20366  4868.222801
# F9       2015        1      1          22          4      20436   801.793722
# HA       2015        1      1          22          4      19690   229.125000
# MQ       2015        1      1          22          4      20398  3292.123885
# NK       2015        1      1          22          4      20416   531.857651
# OO       2015        1      1          22          4      20304  5119.277847
# UA       2015        1      1          22          4      19977  1002.367286
# ...

# %%
by_carrier.size()
# Out:
# Carrier
# AA    1443
# AS     436
# B6     710
# DL    2304
# EV    1728
# F9     223
# HA     208
# MQ    1009
# NK     281
# OO    1616
# UA    1345
# US    1171
# VX     163
# WN    3376
# dtype: int64

# %%
by_carrier.agg(['mean','count'])
# Out:
#          Year       Quarter       Month       DayofMonth       DayOfWeek  \
#          mean count    mean count  mean count       mean count      mean
# Carrier
# AA       2015  1443       1  1443     1  1443         22  1443         4
# AS       2015   436       1   436     1   436         22   436         4
# B6       2015   710       1   710     1   710         22   710         4
# DL       2015  2304       1  2304     1  2304         22  2304         4
# EV       2015  1728       1  1728     1  1728         22  1728         4
# F9       2015   223       1   223     1   223         22   223         4
# HA       2015   208       1   208     1   208         22   208         4
# MQ       2015  1009       1  1009     1  1009         22  1009         4
# NK       2015   281       1   281     1   281         22   281         4
# OO       2015  1616       1  1616     1  1616         22  1616         4
# UA       2015  1345       1  1345     1  1345         22  1345         4
# ...

# %%
daystatistics = by_carrier['DayofMonth'].agg(['mean','count','size'])

# %%
daystatistics['Coverage'] = daystatistics['count']/len(df)

# %%
daystatistics
# Out:
#          mean  count  size  Coverage
# Carrier
# AA         22   1443  1443  0.003070
# AS         22    436   436  0.000928
# B6         22    710   710  0.001511
# DL         22   2304  2304  0.004902
# EV         22   1728  1728  0.003677
# F9         22    223   223  0.000475
# HA         22    208   208  0.000443
# MQ         22   1009  1009  0.002147
# NK         22    281   281  0.000598
# OO         22   1616  1616  0.003439
# UA         22   1345  1345  0.002862
# US         22   1171  1171  0.002492
# VX         22    163   163  0.000347
# WN         22   3376  3376  0.007183

# %%
def cover(s):
    return round(100*float(s['count'])/float(len(df)),2)

# %%
daystatistics['Coverage2']=daystatistics.apply(cover,axis=1)

# %%
daystatistics
# Out:
#          mean  count  size  Coverage  Coverage2
# Carrier
# AA         22   1443  1443  0.003070       0.31
# AS         22    436   436  0.000928       0.09
# B6         22    710   710  0.001511       0.15
# DL         22   2304  2304  0.004902       0.49
# EV         22   1728  1728  0.003677       0.37
# F9         22    223   223  0.000475       0.05
# HA         22    208   208  0.000443       0.04
# MQ         22   1009  1009  0.002147       0.21
# NK         22    281   281  0.000598       0.06
# OO         22   1616  1616  0.003439       0.34
# UA         22   1345  1345  0.002862       0.29
# US         22   1171  1171  0.002492       0.25
# VX         22    163   163  0.000347       0.03
# WN         22   3376  3376  0.007183       0.72

# %%
for key, df in by_carrier:
    print len(df)
# Out:
# 1443
# 436
# 710
# 2304
# 1728
# 223
# 208
# 1009
# 281
# 1616
# 1345
# 1171
# 163
# 3376
